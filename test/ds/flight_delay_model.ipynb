# %%
import pandas as pd
import numpy as np
import requests
import json
import io

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

import joblib

# %%
url_json = 'https://raw.githubusercontent.com/DnRiv/Proyecto-3-FlightOnTime-Predicci-n-de-Retrasos-de-Vuelos/refs/heads/main/ds/data/vuelos_mock.csv'

# %%
response = requests.get(url_json)
df = pd.read_csv(io.StringIO(response.text))

# %%
df.head()
# Out:
#    hora  dia_semana  distancia  retrasado  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0   8.0         1.0      300.0        0.0         NaN         NaN         NaN
# 1  18.0         5.0     1200.0        1.0         NaN         NaN         NaN
# 2  22.0         6.0      800.0        1.0         NaN         NaN         NaN
# 3   9.0         2.0      400.0        0.0         NaN         NaN         NaN
# 4   NaN         NaN        NaN        NaN         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
df = df[['hora','dia_semana', 'distancia', 'retrasado']]
df.head()
# Out:
#    hora  dia_semana  distancia  retrasado
# 0   8.0         1.0      300.0        0.0
# 1  18.0         5.0     1200.0        1.0
# 2  22.0         6.0      800.0        1.0
# 3   9.0         2.0      400.0        0.0
# 4   NaN         NaN        NaN        NaN

# %%
df = df.astype('Int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   hora        4 non-null      Int64
#  1   dia_semana  4 non-null      Int64
#  2   distancia   4 non-null      Int64
#  3   retrasado   4 non-null      Int64
# dtypes: Int64(4)
# memory usage: 456.0 bytes

# %%
df = df.head(4)

# %%
X = df[["hora", "dia_semana", "distancia"]]
y = df["retrasado"]

# %%
X.head()
# Out:
#    hora  dia_semana  distancia
# 0     8           1        300
# 1    18           5       1200
# 2    22           6        800
# 3     9           2        400

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

accuracy
# Out:
# 1.0

# %%
ejemplo_vuelo = pd.DataFrame([{
    "hora": 19,
    "dia_semana": 5,
    "distancia": 1200
}])

prob = model.predict_proba(ejemplo_vuelo)[0][1]
prob
# Out:
# np.float64(0.9999999999801699)

# %%
"Retrasado" if prob > 0.5 else "Puntual"
# Out:
# 'Retrasado'

# %%
joblib.dump(model, "model.joblib")
# Out:
# ['model.joblib']
